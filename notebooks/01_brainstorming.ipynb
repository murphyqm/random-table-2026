# %% [markdown]
# Random table generator
#
# - Take in csv files (future: maybe excel?)
# - Csv file can have any number of columns, each column has a header/title (within reason)
# - Columns can have different lengths
#
# - need to make an example csv file
# - happy for it to run in a jupyter notebook

# %%
import pandas as pd

# %%
# function to load csv file

example_table = pd.read_csv("../data/example-table.csv")

# %%
example_table.columns = example_table.columns.str.strip()
example_table.columns
# Out:
# Index(['Weather', 'Time of day', 'Environment', 'Environmental Hazard',
#        'NPCs'],
#       dtype='str')

# %%
example_table["Weather"]
# Out:
# 0     Sunny
# 1    Stormy
# 2     Snowy
# 3       NaN
# 4       NaN
# 5       NaN
# Name: Weather, dtype: str

# %%
def load_table(filepath):
    example_table = pd.read_csv(filepath)
    example_table.columns = example_table.columns.str.strip()
    return example_table

# %%
example_table_2 = load_table("../data/example-table.csv")

# %%
example_table_2.columns
# Out:
# Index(['Weather', 'Time of day', 'Environment', 'Environmental Hazard',
#        'NPCs'],
#       dtype='str')

# %%
# function to remind me what categories are available

# %%
# function that given a category, will randomly select one and print it
