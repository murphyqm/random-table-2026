# %%
import random_tables as rt

# %%
table = rt.load_table("../data/example-table.csv")

# %%
table.columns
# Out:
# Index(['Weather', 'Time of day', 'Environment', 'Environmental Hazard',
#        'NPCs'],
#       dtype='str')

# %%
table.columns.to_list()
# Out:
# ['Weather', 'Time of day', 'Environment', 'Environmental Hazard', 'NPCs']

# %%
rt.categories()
# Out:
# ['Weather', 'Time of day', 'Environment', 'Environmental Hazard', 'NPCs']

# %%
rt.select('Environmental Hazard')
# Out:
# 'Landslide'
